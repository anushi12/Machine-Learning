# %%
import os

# %%
## create a new directory
new_directory = "package"
os.mkdir(new_directory)
print(f"Directory '{new_directory}' created")
# Out:
# Directory 'package' created

# %%
## Listing Files and Directories
items = os.listdir('.')
print(items)
# Out:
# ['destination.txt', '6.1-fileOperation.ipynb', '6.2-filepath.ipynb', 'myfile.txt', 'package', 'Binary.bin']

# %%
## joining paths --> relative path

dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(dir_name,file_name)

print(full_path)
# Out:
# folder/file.txt

# %%
## to get the entire path --> absolute path
dir_name = 'folder'
file_name = 'file.txt'
full_path = os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# /Users/dolphin_olivia/Desktop/Python/6-File Handling/folder/file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f"the path '{path}' exists")
else:
    print(f"the path '{path}' does not exits")
# Out:
# the path 'example.txt' does not exits

# %%
## checking if a path is a file or directory

import os

path = 'myfile.txt'
if os.path.isfile(path):
    print("path is a file")
elif os.path.isdir(path):
    print("path is a directory")
else:
    print("path is neither a file nor a directory")
# Out:
# path is a file

# %%
## getting the relative path

relative_path = "myfile.txt"
absolute_path = os.path.abspath(relative_path)
print(absolute_path)
# Out:
# /Users/dolphin_olivia/Desktop/Python/6-File Handling/myfile.txt
