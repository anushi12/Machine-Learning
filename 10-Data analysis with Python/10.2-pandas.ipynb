# %% [markdown]
# ### Pandas-DataFrame And Series
#
# Pandas is a powerful data manipulation library in python, widely used for data analysis and data cleaning. It provides two primary data structures: Series and DataFrame. A Series is one-dimensional array-like object, while a DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns).

# %%
import pandas as pd

# %%
## Series ---> A 1-D array like object that can hold any data type.
import pandas as pd
data = [1,2,3,4,5]
series = pd.Series(data)
print(series)
print(type(series))
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
## create a series from dictionary elements

data = {'a': 1, 'b':2, 'c':3}
series_dict = pd.Series(data)
print(series_dict)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data = [10,20,30]
index = ['a','b','c']
pd.Series(data,index)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
## DataFrame

## create a dataframe from a dictionary of list
data = {
    'name':['anush','puneet','jack','david'],
    'Age':[34,45,32,56],
    'city': ['Monton','chicago','Florida','Toronto']
}
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#      name  Age     city
# 0   anush   34   Monton
# 1  puneet   45  chicago
# 2    jack   32  Florida
# 3   david   56  Toronto
# <class 'pandas.core.frame.DataFrame'>

# %%
## create a dataframe from a list of dictionaries

data = [
    {'name':'anush', 'Age':34, 'City':'Monton'},
    {'name':'puneet', 'Age':45, 'City':'Chicago'},
    {'name':'jack', 'Age':32, 'City':'Florida'},
    {'name':'david', 'Age':56, 'City':'Ohio'},
]
df = pd.DataFrame(data)
print(df)
# Out:
#      name  Age     City
# 0   anush   34   Monton
# 1  puneet   45  Chicago
# 2    jack   32  Florida
# 3   david   56     Ohio

# %%
df = pd.read_csv("coffee_shop_sales.csv")

# %%
df.head(5)
# Out:
#          Date        Day         Branch       Drink   Size  Quantity  Price  \
# 0  2025-10-01  Wednesday  The Bean Spot       Latte  Small         5    180
# 1  2025-10-02   Thursday     Brew Bliss  Flat White  Large         1    150
# 2  2025-10-03     Friday   Latte Lounge   Americano  Small         5    180
# 3  2025-10-04   Saturday     Brew Bliss   Americano  Small         4    150
# 4  2025-10-05     Sunday  The Bean Spot   Americano  Large         2    120
#
#    Total_Sale  Customer_Rating
# 0         900              4.2
# 1         150              4.2
# 2         900              3.4
# 3         600              3.9
# 4         240              4.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date             50 non-null     object
#  1   Day              50 non-null     object
#  2   Branch           50 non-null     object
#  3   Drink            50 non-null     object
#  4   Size             50 non-null     object
#  5   Quantity         50 non-null     int64
#  6   Price            50 non-null     int64
#  7   Total_Sale       50 non-null     int64
#  8   Customer_Rating  50 non-null     float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.6+ KB

# %%
df.describe()
# Out:
#        Quantity       Price   Total_Sale  Customer_Rating
# count  50.00000   50.000000    50.000000        50.000000
# mean    2.92000  168.800000   502.200000         3.910000
# std     1.35285   35.550481   273.027546         0.536143
# min     1.00000  120.000000   120.000000         3.000000
# 25%     2.00000  150.000000   255.000000         3.500000
# 50%     3.00000  165.000000   450.000000         3.900000
# 75%     4.00000  200.000000   660.000000         4.400000
# max     5.00000  220.000000  1100.000000         5.000000

# %%
df.tail(5)
# Out:
#           Date        Day         Branch       Drink    Size  Quantity  Price  \
# 45  2025-11-15   Saturday  The Bean Spot  Flat White  Medium         2    200
# 46  2025-11-16     Sunday     Brew Bliss   Americano  Medium         5    220
# 47  2025-11-17     Monday     Brew Bliss  Cappuccino  Medium         2    150
# 48  2025-11-18    Tuesday   Latte Lounge    Espresso   Large         1    200
# 49  2025-11-19  Wednesday  The Bean Spot  Flat White   Large         4    200
#
#     Total_Sale  Customer_Rating
# 45         400              4.7
# 46        1100              3.7
# 47         300              3.5
# 48         200              4.7
# 49         800              3.3

# %%
## Accessing data from data frame

df["Branch"]
# Out:
# 0     The Bean Spot
# 1        Brew Bliss
# 2      Latte Lounge
# 3        Brew Bliss
# 4     The Bean Spot
# 5     The Bean Spot
# 6        Brew Bliss
# 7     The Bean Spot
# 8        Cafe Aroma
# 9        Cafe Aroma
# 10       Brew Bliss
# 11     Latte Lounge
# 12       Cafe Aroma
# 13       Cafe Aroma
# 14    The Bean Spot
# 15       Brew Bliss
# 16    The Bean Spot
# 17       Brew Bliss
# 18       Brew Bliss
# 19     Latte Lounge
# 20       Cafe Aroma
# 21    The Bean Spot
# 22       Brew Bliss
# 23       Brew Bliss
# 24       Brew Bliss
# 25       Brew Bliss
# 26       Cafe Aroma
# 27       Brew Bliss
# 28     Latte Lounge
# 29     Latte Lounge
# 30     Latte Lounge
# 31    The Bean Spot
# 32       Brew Bliss
# 33     Latte Lounge
# 34     Latte Lounge
# 35       Cafe Aroma
# 36       Brew Bliss
# 37       Brew Bliss
# 38    The Bean Spot
# 39     Latte Lounge
# 40       Brew Bliss
# 41       Cafe Aroma
# 42     Latte Lounge
# 43       Cafe Aroma
# 44    The Bean Spot
# 45    The Bean Spot
# 46       Brew Bliss
# 47       Brew Bliss
# 48     Latte Lounge
# 49    The Bean Spot
# Name: Branch, dtype: object

# %%
df.loc[0]   ## row index
# Out:
# Date                  2025-10-01
# Day                    Wednesday
# Branch             The Bean Spot
# Drink                      Latte
# Size                       Small
# Quantity                       5
# Price                        180
# Total_Sale                   900
# Customer_Rating              4.2
# Name: 0, dtype: object

# %%
df.iloc[0][2]       ## column index
# Out:
# /var/folders/96/rx30xz2d5jn8zh1n7bz40frw0000gn/T/ipykernel_3287/2519637664.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df.iloc[0][2]
# 'The Bean Spot'

# %%
## Accessing a specified element
df.at[3, "Branch"]  ## fetches the value at particular position
# Out:
# 'Brew Bliss'

# %%
## iat

df.iat[2,2]
# Out:
# 'Latte Lounge'

# %%
## data manipulation with dataframes
data = {
    'name':['anush','puneet','jack','david'],
    'Age':[34,45,32,56],
    'city': ['Monton','chicago','Florida','Toronto']
}
df = pd.DataFrame(data)
print(df)
# Out:
#      name  Age     city
# 0   anush   34   Monton
# 1  puneet   45  chicago
# 2    jack   32  Florida
# 3   david   56  Toronto

# %%
df['Salary'] = [150000, 100000, 90000, 200000]
df
# Out:
#      name  Age     city  Salary
# 0   anush   36   Monton  150000
# 1  puneet   47  chicago  100000
# 2    jack   34  Florida   90000
# 3   david   58  Toronto  200000

# %%
df.drop('Salary', axis = 1)       ## by default axis = 0 (row)
## drop removes a column temporarily
# Out:
#      name  Age     city
# 0   anush   36   Monton
# 1  puneet   47  chicago
# 2    jack   34  Florida
# 3   david   58  Toronto

# %%
df
# Out:
#      name  Age     city  Salary
# 0   anush   36   Monton  150000
# 1  puneet   47  chicago  100000
# 2    jack   34  Florida   90000
# 3   david   58  Toronto  200000

# %%
df.drop('Salary', axis = 1, inplace = True)     ## removes permanently

# %%
df
# Out:
#      name  Age     city
# 0   anush   36   Monton
# 1  puneet   47  chicago
# 2    jack   34  Florida
# 3   david   58  Toronto

# %%
## Add age to the column
df['Age'] = df['Age']+1
df
# Out:
#      name  Age     city
# 0   anush   37   Monton
# 1  puneet   48  chicago
# 2    jack   35  Florida
# 3   david   59  Toronto

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   44.750000
# std    11.086779
# min    35.000000
# 25%    36.500000
# 50%    42.500000
# 75%    50.750000
# max    59.000000
