# %% [markdown]
# ### Data Maipulation and Analysis with Pandas
#
# Data manipulation and analysis are key tasks in any data science or data analysis project. Pandas provides a wide range of functions for data manipulation and analysis, making it easier to clean, transform and extract insights from data.

# %%
import pandas as pd

# %%
df = pd.read_csv("coffee_shop_sales (10.3).csv")
df.head()
# Out:
#          Date Transaction_ID Customer_Name   Age Gender              Item  \
# 0  2025-10-01           T001   Arjun Mehta  25.0      M             Latte
# 1  2025-10-01           T002   Simran Kaur  31.0      F        Cappuccino
# 2  2025-10-02           T003  Rahul Sharma   NaN      M  Blueberry Muffin
# 3  2025-10-02           T004    Neha Singh  27.0      F          Espresso
# 4  2025-10-03           T005  Manish Gupta  45.0      M         Americano
#
#   Category  Quantity  Price Payment_Method           Branch  Rating
# 0    Drink       2.0  150.0           Cash  Connaught Place     4.0
# 1    Drink       1.0  180.0           Card  Connaught Place     5.0
# 2     Food       1.0  120.0            UPI            Saket     3.0
# 3    Drink       1.0    NaN           Cash        Hauz Khas     4.0
# 4    Drink       3.0  140.0           Card        Hauz Khas     NaN

# %%
df.describe()
# Out:
#              Age   Quantity       Price     Rating
# count  12.000000  14.000000   13.000000  12.000000
# mean   31.000000   1.357143  166.153846   4.166667
# std     6.410219   0.633324   43.308671   0.834847
# min    23.000000   1.000000  100.000000   3.000000
# 25%    26.750000   1.000000  140.000000   3.750000
# 50%    29.500000   1.000000  150.000000   4.000000
# 75%    33.500000   1.750000  190.000000   5.000000
# max    45.000000   3.000000  250.000000   5.000000

# %%
df.dtypes
# Out:
# Date               object
# Transaction_ID     object
# Customer_Name      object
# Age               float64
# Gender             object
# Item               object
# Category           object
# Quantity          float64
# Price             float64
# Payment_Method     object
# Branch             object
# Rating            float64
# dtype: object

# %%
## Handling missing values
## isnull() --> helps to find null values and gives a boolean value
## any() --> gives which particular column has got null values
df.isnull().any()
# Out:
# Date              False
# Transaction_ID    False
# Customer_Name     False
# Age                True
# Gender            False
# Item              False
# Category          False
# Quantity           True
# Price              True
# Payment_Method     True
# Branch             True
# Rating             True
# dtype: bool

# %%
## sum() --> helps find the number of null values in particular column
df.isnull().sum()
# Out:
# Date              0
# Transaction_ID    0
# Customer_Name     0
# Age               3
# Gender            0
# Item              0
# Category          0
# Quantity          1
# Price             2
# Payment_Method    1
# Branch            1
# Rating            3
# dtype: int64

# %%
## filling missing values with the mean of the column
## fillna() -> is a function that is used to fill the null values

df['Age_fillNA'] = df['Age'].fillna(df['Age'].mean())
df
# Out:
#           Date Transaction_ID Customer_Name   Age Gender                 Item  \
# 0   2025-10-01           T001   Arjun Mehta  25.0      M                Latte
# 1   2025-10-01           T002   Simran Kaur  31.0      F           Cappuccino
# 2   2025-10-02           T003  Rahul Sharma   NaN      M     Blueberry Muffin
# 3   2025-10-02           T004    Neha Singh  27.0      F             Espresso
# 4   2025-10-03           T005  Manish Gupta  45.0      M            Americano
# 5   2025-10-03           T006   Aarti Patel   NaN      F  Chocolate Croissant
# 6   2025-10-04           T007   Kunal Verma  30.0      M                Mocha
# 7   2025-10-04           T008  Priya Bansal  23.0      F                Latte
# 8   2025-10-05           T009  Ritika Joshi  26.0      F      Cheese Sandwich
# 9   2025-10-05           T010   Sameer Khan  35.0      M            Cold Brew
# 10  2025-10-06           T011     Tanya Raj   NaN      F                Mocha
# 11  2025-10-06           T012   Deepak Rana  29.0      M       Chocolate Cake
# 12  2025-10-07           T013   Neeraj Nair  40.0      M             Espresso
# 13  2025-10-07           T014  Megha Kapoor  28.0      F                Latte
# 14  2025-10-08           T015    Ashok Jain  33.0      M     Blueberry Muffin
#
#    Category  Quantity  Price Payment_Method           Branch  Rating  \
# 0     Drink       2.0  150.0           Cash  Connaught Place     4.0
# 1     Drink       1.0  180.0           Card  Connaught Place     5.0
# 2      Food       1.0  120.0            UPI            Saket     3.0
# 3     Drink       1.0    NaN           Cash        Hauz Khas     4.0
# 4     Drink       3.0  140.0           Card        Hauz Khas     NaN
# 5      Food       2.0  200.0            NaN            Saket     5.0
# 6     Drink       1.0  190.0            UPI  Connaught Place     4.0
# 7     Drink       1.0  150.0           Card            Saket     5.0
# 8      Food       NaN  220.0           Cash        Hauz Khas     3.0
# 9     Drink       1.0  250.0           Card  Connaught Place     4.0
# 10    Drink       1.0  190.0            UPI            Saket     NaN
# 11     Food       1.0    NaN           Card  Connaught Place     5.0
# 12    Drink       2.0  100.0           Cash        Hauz Khas     3.0
# 13    Drink       1.0  150.0            UPI              NaN     5.0
# 14     Food       1.0  120.0           Card  Connaught Place     NaN
#
#     Age_fillNA
# 0         25.0
# 1         31.0
# 2         31.0
# 3         27.0
# 4         45.0
# 5         31.0
# 6         30.0
# 7         23.0
# 8         26.0
# 9         35.0
# 10        31.0
# 11        29.0
# 12        40.0
# 13        28.0
# 14        33.0

# %%
## rating
df['Rating_fillna'] = df['Rating'].fillna(df['Rating'].mean())
df
# Out:
#           Date Transaction_ID Customer_Name   Age Gender                 Item  \
# 0   2025-10-01           T001   Arjun Mehta  25.0      M                Latte
# 1   2025-10-01           T002   Simran Kaur  31.0      F           Cappuccino
# 2   2025-10-02           T003  Rahul Sharma   NaN      M     Blueberry Muffin
# 3   2025-10-02           T004    Neha Singh  27.0      F             Espresso
# 4   2025-10-03           T005  Manish Gupta  45.0      M            Americano
# 5   2025-10-03           T006   Aarti Patel   NaN      F  Chocolate Croissant
# 6   2025-10-04           T007   Kunal Verma  30.0      M                Mocha
# 7   2025-10-04           T008  Priya Bansal  23.0      F                Latte
# 8   2025-10-05           T009  Ritika Joshi  26.0      F      Cheese Sandwich
# 9   2025-10-05           T010   Sameer Khan  35.0      M            Cold Brew
# 10  2025-10-06           T011     Tanya Raj   NaN      F                Mocha
# 11  2025-10-06           T012   Deepak Rana  29.0      M       Chocolate Cake
# 12  2025-10-07           T013   Neeraj Nair  40.0      M             Espresso
# 13  2025-10-07           T014  Megha Kapoor  28.0      F                Latte
# 14  2025-10-08           T015    Ashok Jain  33.0      M     Blueberry Muffin
#
#    Category  Quantity  Price Payment_Method           Branch  Rating  \
# 0     Drink       2.0  150.0           Cash  Connaught Place     4.0
# 1     Drink       1.0  180.0           Card  Connaught Place     5.0
# 2      Food       1.0  120.0            UPI            Saket     3.0
# 3     Drink       1.0    NaN           Cash        Hauz Khas     4.0
# 4     Drink       3.0  140.0           Card        Hauz Khas     NaN
# 5      Food       2.0  200.0            NaN            Saket     5.0
# 6     Drink       1.0  190.0            UPI  Connaught Place     4.0
# 7     Drink       1.0  150.0           Card            Saket     5.0
# 8      Food       NaN  220.0           Cash        Hauz Khas     3.0
# 9     Drink       1.0  250.0           Card  Connaught Place     4.0
# 10    Drink       1.0  190.0            UPI            Saket     NaN
# 11     Food       1.0    NaN           Card  Connaught Place     5.0
# 12    Drink       2.0  100.0           Cash        Hauz Khas     3.0
# 13    Drink       1.0  150.0            UPI              NaN     5.0
# 14     Food       1.0  120.0           Card  Connaught Place     NaN
#
#     Age_fillNA  Rating_fillna
# 0         25.0       4.000000
# 1         31.0       5.000000
# 2         31.0       3.000000
# 3         27.0       4.000000
# 4         45.0       4.166667
# 5         31.0       5.000000
# 6         30.0       4.000000
# 7         23.0       5.000000
# 8         26.0       3.000000
# 9         35.0       4.000000
# 10        31.0       4.166667
# 11        29.0       5.000000
# 12        40.0       3.000000
# 13        28.0       5.000000
# 14        33.0       4.166667

# %%
## Rename column
df = df.rename(columns = {'Price':'Amount'})
df.head()
# Out:
#          Date Transaction_ID Customer_Name   Age Gender              Item  \
# 0  2025-10-01           T001   Arjun Mehta  25.0      M             Latte
# 1  2025-10-01           T002   Simran Kaur  31.0      F        Cappuccino
# 2  2025-10-02           T003  Rahul Sharma   NaN      M  Blueberry Muffin
# 3  2025-10-02           T004    Neha Singh  27.0      F          Espresso
# 4  2025-10-03           T005  Manish Gupta  45.0      M         Americano
#
#   Category  Quantity  Amount Payment_Method           Branch  Rating
# 0    Drink       2.0   150.0           Cash  Connaught Place     4.0
# 1    Drink       1.0   180.0           Card  Connaught Place     5.0
# 2     Food       1.0   120.0            UPI            Saket     3.0
# 3    Drink       1.0     NaN           Cash        Hauz Khas     4.0
# 4    Drink       3.0   140.0           Card        Hauz Khas     NaN

# %%
## change the data types
df['Amount_new']=df['Amount'].fillna(df['Amount'].mean())
df.head()
# Out:
#          Date Transaction_ID Customer_Name   Age Gender              Item  \
# 0  2025-10-01           T001   Arjun Mehta  25.0      M             Latte
# 1  2025-10-01           T002   Simran Kaur  31.0      F        Cappuccino
# 2  2025-10-02           T003  Rahul Sharma   NaN      M  Blueberry Muffin
# 3  2025-10-02           T004    Neha Singh  27.0      F          Espresso
# 4  2025-10-03           T005  Manish Gupta  45.0      M         Americano
#
#   Category  Quantity  Amount Payment_Method           Branch  Rating  \
# 0    Drink       2.0   150.0           Cash  Connaught Place     4.0
# 1    Drink       1.0   180.0           Card  Connaught Place     5.0
# 2     Food       1.0   120.0            UPI            Saket     3.0
# 3    Drink       1.0     NaN           Cash        Hauz Khas     4.0
# 4    Drink       3.0   140.0           Card        Hauz Khas     NaN
#
#    Amount_new
# 0  150.000000
# 1  180.000000
# 2  120.000000
# 3  166.153846
# 4  140.000000

# %%
df['Amount_int']=df['Amount_new'].astype(int)
df.head()
# Out:
#          Date Transaction_ID Customer_Name   Age Gender              Item  \
# 0  2025-10-01           T001   Arjun Mehta  25.0      M             Latte
# 1  2025-10-01           T002   Simran Kaur  31.0      F        Cappuccino
# 2  2025-10-02           T003  Rahul Sharma   NaN      M  Blueberry Muffin
# 3  2025-10-02           T004    Neha Singh  27.0      F          Espresso
# 4  2025-10-03           T005  Manish Gupta  45.0      M         Americano
#
#   Category  Quantity  Amount Payment_Method           Branch  Rating  \
# 0    Drink       2.0   150.0           Cash  Connaught Place     4.0
# 1    Drink       1.0   180.0           Card  Connaught Place     5.0
# 2     Food       1.0   120.0            UPI            Saket     3.0
# 3    Drink       1.0     NaN           Cash        Hauz Khas     4.0
# 4    Drink       3.0   140.0           Card        Hauz Khas     NaN
#
#    Amount_new  Amount_int
# 0  150.000000         150
# 1  180.000000         180
# 2  120.000000         120
# 3  166.153846         166
# 4  140.000000         140

# %%
df['Increased_Price'] = df['Amount'].apply(lambda x:x*2)
df.head()
# Out:
#          Date Transaction_ID Customer_Name   Age Gender              Item  \
# 0  2025-10-01           T001   Arjun Mehta  25.0      M             Latte
# 1  2025-10-01           T002   Simran Kaur  31.0      F        Cappuccino
# 2  2025-10-02           T003  Rahul Sharma   NaN      M  Blueberry Muffin
# 3  2025-10-02           T004    Neha Singh  27.0      F          Espresso
# 4  2025-10-03           T005  Manish Gupta  45.0      M         Americano
#
#   Category  Quantity  Amount Payment_Method           Branch  Rating  \
# 0    Drink       2.0   150.0           Cash  Connaught Place     4.0
# 1    Drink       1.0   180.0           Card  Connaught Place     5.0
# 2     Food       1.0   120.0            UPI            Saket     3.0
# 3    Drink       1.0     NaN           Cash        Hauz Khas     4.0
# 4    Drink       3.0   140.0           Card        Hauz Khas     NaN
#
#    Amount_new  Amount_int  Increased_Price
# 0  150.000000         150            300.0
# 1  180.000000         180            360.0
# 2  120.000000         120            240.0
# 3  166.153846         166              NaN
# 4  140.000000         140            280.0

# %%
## Data Aggregating and grouping

grouped_mean = df.groupby('Item')['Amount'].mean()
print(grouped_mean)
# Out:
# Item
# Americano              140.0
# Blueberry Muffin       120.0
# Cappuccino             180.0
# Cheese Sandwich        220.0
# Chocolate Cake           NaN
# Chocolate Croissant    200.0
# Cold Brew              250.0
# Espresso               100.0
# Latte                  150.0
# Mocha                  190.0
# Name: Amount, dtype: float64

# %%
grouped_sum = df.groupby(['Item', 'Branch'])['Amount'].sum()
print(grouped_sum)
# Out:
# Item                 Branch
# Americano            Hauz Khas          140.0
# Blueberry Muffin     Connaught Place    120.0
#                      Saket              120.0
# Cappuccino           Connaught Place    180.0
# Cheese Sandwich      Hauz Khas          220.0
# Chocolate Cake       Connaught Place      0.0
# Chocolate Croissant  Saket              200.0
# Cold Brew            Connaught Place    250.0
# Espresso             Hauz Khas          100.0
# Latte                Connaught Place    150.0
#                      Saket              150.0
# Mocha                Connaught Place    190.0
#                      Saket              190.0
# Name: Amount, dtype: float64

# %%
## aggregate multiple functions

grouped_agg = df.groupby('Branch')['Amount'].agg(['mean','sum','count'])
print(grouped_agg)
# Out:
#                        mean    sum  count
# Branch
# Connaught Place  178.000000  890.0      5
# Hauz Khas        153.333333  460.0      3
# Saket            165.000000  660.0      4

# %%
## Merging and joining data frames

df1 = pd.DataFrame({'Id': [1,2,3], 'Name': ['anushka','puneet','jack']})
df2 = pd.DataFrame({'Id': [1,2,3], 'City': ['Menton','Delhi','Bengalore']})
pd.merge(df1,df2,on = 'Id')
# Out:
#    Id     Name       City
# 0   1  anushka     Menton
# 1   2   puneet      Delhi
# 2   3     jack  Bengalore

# %%
df1 = pd.DataFrame({'Id': [1,2,4], 'Name': ['anushka','puneet','jack']})
df2 = pd.DataFrame({'Id': [1,2,3], 'City': ['Menton','Delhi','Bengalore']})
pd.merge(df1,df2,on = 'Id', how ='outer')
# Out:
#    Id     Name       City
# 0   1  anushka     Menton
# 1   2   puneet      Delhi
# 2   3      NaN  Bengalore
# 3   4     jack        NaN

# %%
pd.merge(df1,df2,on = 'Id', how ='left')
# Out:
#    Id     Name    City
# 0   1  anushka  Menton
# 1   2   puneet   Delhi
# 2   4     jack     NaN

# %%
pd.merge(df1,df2,on = 'Id', how ='right')
# Out:
#    Id     Name       City
# 0   1  anushka     Menton
# 1   2   puneet      Delhi
# 2   3      NaN  Bengalore
