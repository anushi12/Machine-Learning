# %% [markdown]
# Syntax and Semantics in Python
#
# - Single line comments and multiline comments
# - Definition of Syntax and Semantics

# %% [markdown]
# Syntax refers to the set of rules that defines the combinations of symbols that are considered to be correctly structured programs in a language. In simpler terms, syntax is about the correct arrangement of words and symbols in a code.

# %% [markdown]
# Semantics refers to the meaning or the interpretation of the symbols, characters, and commands in a language. It is about what the code is supposed to do when it runs.

# %% [markdown]
# ## Basic syntax rules in python

# %%
## Python is case sensitive ------> single line comment

name = "Anusha"
Name = "Das" 

'''Both are same name but different variables''' ## (''' ''' for multiline comments)

print(name + " " + Name)
# Out:
# Anusha Das

# %% [markdown]
# ## Indentation
# In python, indentation is used to define the structure and hierarchy of code. Unlike many other programming languages that use braces {} to delimit blocks of code, Python uses indentation to determine the grouping of statements. This means that all the statements within a block must be indented at the same level.

# %%
age = 42
if age > 30:
    print(age)

print(age)
# Out:
# 42
# 42

# %%
## Line Continuation
## use a backslash (\) to continue a statement to the next level

total = 1 + 2 + 3 + 4 + 5 +\
7+5+9

print(total)
# Out:
# 36
