# %%
import array 
arr = array.array('i', [1,2,3,4])
print(arr)
# Out:
# array('i', [1, 2, 3, 4])

# %%
import math
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
## random

import random
print(random.randint(1,10))
print(random.choice(['apple','banana','cherry']))
# Out:
# 9
# cherry

# %%
## file and directory access

import os
print(os.getcwd())
# Out:
# /Users/dolphin_olivia/Desktop/Python/5-Modules

# %%
os.mkdir('test_dir')

# %%
## high level operation on files and collection of files
import shutil
shutil.copyfile('source.txt','destination.txt')
# Out:
# 'destination.txt'

# %%
## data serialization

import json
data = {'name':'Anush', 'age':56}

json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Anush", "age": 56}
# <class 'str'>
# {'name': 'Anush', 'age': 56}
# <class 'dict'>

# %%
## CSV

import csv

with open('example.csv', mode='w', newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['name','age'])
    writer.writerow(['anush','34'])

with open('example.csv',mode='r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['name', 'age']
# ['anush', '34']

# %%
## date time

from datetime import datetime, timedelta

now = datetime.now()
print(now)

yesterday = now-timedelta(days = 1)
print(yesterday)
# Out:
# 2025-10-08 22:30:54.634092
# 2025-10-07 22:30:54.634092

# %%
# time

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1759942906.2638452
# 1759942908.269242

# %%
## regular expression

import re

pattern = r'\d+'
text = "There are 678 apples"
match = re.search(pattern, text)
print(match.group())
# Out:
# 678
