# %%
import logging

logger = logging.basicConfig(
    level = logging.DEBUG,
    format = '%(asctime)s-%(name)s-%(levelname)s-%(message)s',
    datefmt = '%Y-%m-%d %H:%M:%S'
)

## create a logger for module 1
logger1 = logging.getLogger("module1")
logger1.setLevel(logging.DEBUG)

## create a logger for module 2
logger2 = logging.getLogger("module2")
logger2.setLevel(logging.WARNING)

# %%
### log messages

logger1.debug("this is a debug message for module 1")
logger2.warning("this is a warning message for module 2")
logger2.error("this is an error message ")
# Out:
# 2025-11-18 14:59:23-module1-DEBUG-this is a debug message for module 1
# 2025-11-18 14:59:23-module2-WARNING-this is a warning message for module 2
# 2025-11-18 14:59:23-module2-ERROR-this is an error message
